# %% [markdown]
# ## Accuracy Loss Plots 3 (classifer 1)

# %%
## standard library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import pandas as pd
import time
import json
import pickle

#Image processing packages
import cv2
from PIL import Image

## Keras + Tensorflow
from keras.utils.np_utils import to_categorical
from keras.models import load_model
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout, Lambda, Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import Adam, SGD
from keras.preprocessing import image
from keras.utils import np_utils
import tensorflow as tf

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Plotting of Accuracy and Loss for debuggiing
# ### Using architecture of classifier 1

# %%
with open('./cnn_model/classifer_1/model9_hist.pkl','rb') as file_name:
    model9_hist = pickle.load(file_name)

# %%
with open('./cnn_model/classifer_1/model10_hist.pkl','rb') as file_name:
    model10_hist = pickle.load(file_name)

# %%
with open('./cnn_model/classifer_1/model11_hist.pkl','rb') as file_name:
    model11_hist = pickle.load(file_name)

# %%
with open('./cnn_model/classifer_1/model15_hist.pkl','rb') as file_name:
    model15_hist = pickle.load(file_name)

# %%
model9 = load_model('./cnn_model/classifer_1/model9.h5')

# %%
model9.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 18, 18, 64)        0
# ...

# %%
model9.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_5',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model9.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.009999999776482582,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
model10 = load_model('./cnn_model/classifer_1/model10.h5')

# %%
model10.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_9 (Conv2D)            (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 18, 18, 64)        0
# ...

# %%
model10.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_9',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model10.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.009999999776482582,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
model11 = load_model('./cnn_model/classifer_1/model11.h5')

# %%
model11.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_13 (Conv2D)           (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 18, 18, 64)        0
# ...

# %%
model11.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_13',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model11.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.0010000000474974513,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
model15 = load_model('./cnn_model/classifer_1/model15.h5')

# %%
model15.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# ...

# %%
model15.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_1',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model15.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.009999999776482582,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(15,20))

### Model 9
plt.suptitle('Classifer 1, drop out at different layers', fontsize=20)

ax[0,0].plot(model9_hist['acc'])
ax[0,0].plot(model9_hist['val_acc'])
ax[0,0].set_title('model 9 accuracy')
ax[0,0].set_ylabel('accuracy')
ax[0,0].set_xlabel('epoch')
ax[0,0].legend(['train', 'test'], loc='lower right')

ax[0,1].plot(model9_hist['loss'])
ax[0,1].plot(model9_hist['val_loss'])
ax[0,1].set_title('model 9 loss')
ax[0,1].set_ylabel('loss')
ax[0,1].set_xlabel('epoch')
ax[0,1].legend(['train', 'test'], loc='upper right')

### Model 10
ax[1,0].plot(model10_hist['acc'])
ax[1,0].plot(model10_hist['val_acc'])
ax[1,0].set_title('model 10 accuracy')
ax[1,0].set_ylabel('accuracy')
ax[1,0].set_xlabel('epoch')
ax[1,0].legend(['train', 'test'], loc='lower right')

ax[1,1].plot(model10_hist['loss'])
ax[1,1].plot(model10_hist['val_loss'])
ax[1,1].set_title('model 10 loss')
ax[1,1].set_ylabel('loss')
ax[1,1].set_xlabel('epoch')
ax[1,1].legend(['train', 'test'], loc='upper right')

### Model 11
ax[2,0].plot(model11_hist['acc'])
ax[2,0].plot(model11_hist['val_acc'])
ax[2,0].set_title('model 11 accuracy')
ax[2,0].set_ylabel('accuracy')
ax[2,0].set_xlabel('epoch')
ax[2,0].legend(['train', 'test'], loc='lower right')

ax[2,1].plot(model11_hist['loss'])
ax[2,1].plot(model11_hist['val_loss'])
ax[2,1].set_title('model 11 loss')
ax[2,1].set_ylabel('loss')
ax[2,1].set_xlabel('epoch')
ax[2,1].legend(['train', 'test'], loc='upper right')

### Model 15
ax[3,0].plot(model15_hist['acc'])
ax[3,0].plot(model15_hist['val_acc'])
ax[3,0].set_title('model 15 accuracy')
ax[3,0].set_ylabel('accuracy')
ax[3,0].set_xlabel('epoch')
ax[3,0].legend(['train', 'test'], loc='lower right')

ax[3,1].plot(model15_hist['loss'])
ax[3,1].plot(model15_hist['val_loss'])
ax[3,1].set_title('model 15 loss')
ax[3,1].set_ylabel('loss')
ax[3,1].set_xlabel('epoch')
ax[3,1].legend(['train', 'test'], loc='upper right')

plt.show()

# %% [markdown]
# model 10 gives the best results (lower the learning rate from 0.01 to 0.001 would be ideal)

# %% [markdown]
# ## Training without shuffling

# %% [markdown]
# Initially I train the model without shuffling the data. There is no convergence for the test set as all the test set are labelled homogenously. This shows the effect of shuffling the data. (IMPORTANT!!)

# %%
with open('./cnn_model/classifer_1/model16_hist.pkl','rb') as file_name:
    model16_hist = pickle.load(file_name)

# %%
model16 = load_model('./cnn_model/classifer_1/model16.h5')

# %%
model16.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_1',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# ...

# %%
model16.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.009999999776482582,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
with open('./cnn_model/classifer_1/model17_hist.pkl','rb') as file_name:
    model17_hist = pickle.load(file_name)

# %%
model17 = load_model('./cnn_model/classifer_1/model17.h5')

# %%
model17.get_config()
# Out:
# [{'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'batch_input_shape': (None, 80, 80, 3),
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
#    'data_format': 'channels_last',
#    'dilation_rate': (1, 1),
#    'dtype': 'float32',
#    'filters': 32,
#    'kernel_constraint': None,
#    'kernel_initializer': {'class_name': 'VarianceScaling',
#     'config': {'distribution': 'uniform',
#      'mode': 'fan_avg',
#      'scale': 1.0,
#      'seed': None}},
#    'kernel_regularizer': None,
#    'kernel_size': (3, 3),
#    'name': 'conv2d_1',
#    'padding': 'same',
#    'strides': (1, 1),
#    'trainable': True,
#    'use_bias': True}},
#  {'class_name': 'Conv2D',
#   'config': {'activation': 'relu',
#    'activity_regularizer': None,
#    'bias_constraint': None,
#    'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#    'bias_regularizer': None,
# ...

# %%
model17.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 80, 80, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 78, 78, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 39, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 39, 39, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 39, 39, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# ...

# %%
model17.optimizer.get_config()
# Out:
# {'decay': 0.0,
#  'lr': 0.0010000000474974513,
#  'momentum': 0.8999999761581421,
#  'nesterov': True}

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,12))

### Model 16
plt.suptitle('Classifer 1 no shuffle training model', fontsize=20)

## Learning rate = 0.01
## Dropout at all layers
ax[0,0].plot(model16_hist['acc'])
ax[0,0].plot(model16_hist['val_acc'])
ax[0,0].set_title('model 16 accuracy')
ax[0,0].set_ylabel('accuracy')
ax[0,0].set_xlabel('epoch')
ax[0,0].legend(['train', 'test'], loc='lower right')

ax[0,1].plot(model16_hist['loss'])
ax[0,1].plot(model16_hist['val_loss'])
ax[0,1].set_title('model 16 loss')
ax[0,1].set_ylabel('loss')
ax[0,1].set_xlabel('epoch')
ax[0,1].legend(['train', 'test'], loc='upper right')

### Model 17

## Learning rate = 0.001
## Dropout at all layers
ax[1,0].plot(model17_hist['acc'])
ax[1,0].plot(model17_hist['val_acc'])
ax[1,0].set_title('model 17 accuracy')
ax[1,0].set_ylabel('accuracy')
ax[1,0].set_xlabel('epoch')
ax[1,0].legend(['train', 'test'], loc='lower right')

ax[1,1].plot(model17_hist['loss'])
ax[1,1].plot(model17_hist['val_loss'])
ax[1,1].set_title('model 17 loss')
ax[1,1].set_ylabel('loss')
ax[1,1].set_xlabel('epoch')
ax[1,1].legend(['train', 'test'], loc='upper right')

plt.show()

# %% [markdown]
# ### something wrong with training, data not shuffle
#
# Next plot show the learning curve for shuffled and non shuffled data

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,12))

### Model 15
plt.suptitle('Shuffling vs no shuffling', fontsize=20)

ax[0,0].plot(model15_hist['acc'])
ax[0,0].plot(model15_hist['val_acc'])
ax[0,0].set_title('model 15 accuracy, shuffled data')
ax[0,0].set_ylabel('accuracy')
ax[0,0].set_xlabel('epoch')
ax[0,0].legend(['train', 'test'], loc='lower right')

ax[0,1].plot(model15_hist['loss'])
ax[0,1].plot(model15_hist['val_loss'])
ax[0,1].set_title('model 15 loss, shuffled data')
ax[0,1].set_ylabel('loss')
ax[0,1].set_xlabel('epoch')
ax[0,1].legend(['train', 'test'], loc='upper right')

### Model 16
ax[1,0].plot(model16_hist['acc'])
ax[1,0].plot(model16_hist['val_acc'])
ax[1,0].set_title('model 16 accuracy, un-shuffled data')
ax[1,0].set_ylabel('accuracy')
ax[1,0].set_xlabel('epoch')
ax[1,0].legend(['train', 'test'], loc='lower right')

ax[1,1].plot(model16_hist['loss'])
ax[1,1].plot(model16_hist['val_loss'])
ax[1,1].set_title('model 16 loss, un-shuffled data')
ax[1,1].set_ylabel('loss')
ax[1,1].set_xlabel('epoch')
ax[1,1].legend(['train', 'test'], loc='upper right')

plt.show()
